# %% [markdown]
# # Seaborn
#
# Seaborn is a statistical plotting library that is specifically designed to interact well with Pandas DataFrames to create common statistical plot types.
#
# Seaborn is directly built off of Matplotlib but uses a simpler "one-line" syntax.
#
# Topics that'll be covered in this section are:
#
# * Scatter Plots
# * Distribution Plots
# * Categorical Plots
# * Comparison Plots
# * Seaborn Grids
# * Matrix Plots

# %% [markdown]
# ## Scatter Plots
#
# Scatter Plots shows the relationship between two continuous features

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('/kaggle/input/dm-sales/dm_office_sales.csv')

df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
# Creating a Scatter Plot. We want to create a scatter plot of salary and sales.
# We'll put salary on the x-axis and sales on the y-axis. To do this, remember, we need to
# pass the names of the columns exactly as they are to sns plot.

sns.scatterplot(x='salary', y='sales', data=df)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
# We can resize the plot even before calling the scatter plot. 

plt.figure(figsize=(12, 4))
sns.scatterplot(x='salary', y='sales', data=df)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
# We can color the dots. Let's say we want to differentiate them based on level of education.
# We can do so by using a parameter called the "hue" parameter

sns.scatterplot(x='salary', y='sales', data=df, hue='level of education')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
# We can enlarge the datapoints. For this, we need to use the "s" parameter

sns.scatterplot(x='salary', y='sales', data=df, hue='level of education', s=200)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
# We can add transparency to the data points by adding the "alpha parameter".
# Alpha parameter takes values between 0 and 1.

sns.scatterplot(x='salary', y='sales', data=df, hue='level of education', s=200, alpha=0.5)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
# Instead of getting each data point at a circle, we can style it based on a column.

sns.scatterplot(x='salary', y='sales', data=df, hue='level of education',style='level of education', s=200)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>
